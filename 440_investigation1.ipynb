# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fmin
import bmxobs

# %%
ch=440
d = bmxobs.BMXObs("pas/210219_1200", channels="440,330")
da=d[ch]
da2=d[330]
plt.plot(da.mean(axis=0))

# %%
plt.plot(da.mean(axis=1))

# %%
plt.plot(1.02/d.temp['fgpa'][:,3])
plt.plot(1.0/d.temp['adc'][:,3])
plt.plot(0.94/d.temp['frontend'][:,3])

# %%
plt.plot(da.mean(axis=1)[44000:46000])

# %%
plt.plot(1.02/d.temp['fgpa'][44000:46000,3])
plt.plot(1.0/d.temp['adc'][44000:46000,3])
plt.plot(0.94/d.temp['frontend'][44000:46000,3])

# %%
x=da[44000:46000]/da[44000:46000].mean(axis=0)[None,:]
plt.imshow(x,aspect='auto')
plt.colorbar()

# %%
plt.plot(x[:,200])
plt.plot(x[:,500])
plt.plot(x[:,1500])
plt.plot(x[:,1700])
plt.plot(x[:,2040])

# %%
x=da2[44000:46000,:]/da2[44000:46000,:].mean(axis=0)[None,:]
plt.imshow(x,aspect='auto',vmin=0.9,vmax=1.1)
plt.colorbar()

# %%
plt.plot(x[:,200])
plt.plot(x[:,500])
plt.plot(x[:,1500])
plt.plot(x[:,1700])
plt.plot(x[:,2040])
