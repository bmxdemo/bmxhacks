# %%
# %load_ext autoreload
# %autoreload 1
# %aimport bmxobs
import matplotlib.pyplot as plt
import numpy as np

# %%
d=bmxobs.BMXObs("pas/200529_0600","all_auto")

# %%
bmxobs.__file__, bmxobs.__path__
# Out:
# ('/astro/u/josborn/.conda/envs/mypy/lib/python3.8/site-packages/bmxobs/__init__.py',
#  ['/astro/u/josborn/.conda/envs/mypy/lib/python3.8/site-packages/bmxobs'])

# %%
d.process_diode()

# %%
d.diode_r[511].mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-c85656c4e751> in <module>
# ----> 1 d.diode_r[511].mean(axis=1)
#
# KeyError: 511

# %%
#plt.plot(d[111][:,(d.freq[1]>1200) & (d.freq[1]<1500)].mean(axis=0))

# %%
plt.plot(d[111][55])

# %%
fig,axes=plt.subplots()
plt.plot(d[111].mean(axis=0))
d.remove_narrow_spikes_V1(1,1,to_self=True)
plt.plot(d[111].mean(axis=0))

axes.set_xlabel('Frequency', fontsize=15)
axes.set_ylabel('Power (ADC unit^2)', fontsize=15)
axes.set_title('Dataset: 200529_0600')
axes.grid(True)
# Out:
# Channel input = 1
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 9.709209 percent complete
# Program is 19.418418 percent complete
# Program is 29.127628 percent complete
# Program is 38.836837 percent complete
# Program is 48.546046 percent complete
# Program is 58.255255 percent complete
# Program is 67.964464 percent complete
# Program is 77.673673 percent complete
# Program is 87.382883 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[111].mean(axis=0))

# %%
plt.plot(d[111].mean(axis=0))
d.remove_narrow_spikes_V1(1,1,to_self=True)
plt.plot(d[111].mean(axis=0))
# Out:
# Channel input = 1
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 9.709209 percent complete
# Program is 19.418418 percent complete
# Program is 29.127628 percent complete
# Program is 38.836837 percent complete
# Program is 48.546046 percent complete
# Program is 58.255255 percent complete
# Program is 67.964464 percent complete
# Program is 77.673673 percent complete
# Program is 87.382883 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[221].mean(axis=0))
d.remove_narrow_spikes_V1(2,1,to_self=True)
plt.plot(d[221].mean(axis=0))
# Out:
# Channel input = 2
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854605 percent complete
# Program is 9.709209 percent complete
# Program is 14.563814 percent complete
# Program is 19.418418 percent complete
# Program is 24.273023 percent complete
# Program is 29.127628 percent complete
# Program is 33.982232 percent complete
# Program is 38.836837 percent complete
# Program is 43.691441 percent complete
# Program is 48.546046 percent complete
# Program is 53.400651 percent complete
# Program is 58.255255 percent complete
# Program is 63.109860 percent complete
# Program is 67.964464 percent complete
# Program is 72.819069 percent complete
# Program is 77.673673 percent complete
# Program is 82.528278 percent complete
# Program is 87.382883 percent complete
# Program is 92.237487 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[331].mean(axis=0))
d.remove_narrow_spikes_V1(3,1,to_self=True)
plt.plot(d[331].mean(axis=0))
# Out:
# Channel input = 3
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854605 percent complete
# Program is 9.709209 percent complete
# Program is 14.563814 percent complete
# Program is 19.418418 percent complete
# Program is 24.273023 percent complete
# Program is 29.127628 percent complete
# Program is 33.982232 percent complete
# Program is 38.836837 percent complete
# Program is 43.691441 percent complete
# Program is 48.546046 percent complete
# Program is 53.400651 percent complete
# Program is 58.255255 percent complete
# Program is 63.109860 percent complete
# Program is 67.964464 percent complete
# Program is 72.819069 percent complete
# Program is 77.673673 percent complete
# Program is 82.528278 percent complete
# Program is 87.382883 percent complete
# Program is 92.237487 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[441].mean(axis=0))
d.remove_narrow_spikes_V1(4,1,to_self=True)
plt.plot(d[441].mean(axis=0))
# Out:
# Channel input = 4
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854605 percent complete
# Program is 9.709209 percent complete
# Program is 14.563814 percent complete
# Program is 19.418418 percent complete
# Program is 24.273023 percent complete
# Program is 29.127628 percent complete
# Program is 33.982232 percent complete
# Program is 38.836837 percent complete
# Program is 43.691441 percent complete
# Program is 48.546046 percent complete
# Program is 53.400651 percent complete
# Program is 58.255255 percent complete
# Program is 63.109860 percent complete
# Program is 67.964464 percent complete
# Program is 72.819069 percent complete
# Program is 77.673673 percent complete
# Program is 82.528278 percent complete
# Program is 87.382883 percent complete
# Program is 92.237487 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[551].mean(axis=0))
d.remove_narrow_spikes_V1(5,1,to_self=True)
plt.plot(d[551].mean(axis=0))
# Out:
# Channel input = 5
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854605 percent complete
# Program is 9.709209 percent complete
# Program is 14.563814 percent complete
# Program is 19.418418 percent complete
# Program is 24.273023 percent complete
# Program is 29.127628 percent complete
# Program is 33.982232 percent complete
# Program is 38.836837 percent complete
# Program is 43.691441 percent complete
# Program is 48.546046 percent complete
# Program is 53.400651 percent complete
# Program is 58.255255 percent complete
# Program is 63.109860 percent complete
# Program is 67.964464 percent complete
# Program is 72.819069 percent complete
# Program is 77.673673 percent complete
# Program is 82.528278 percent complete
# Program is 87.382883 percent complete
# Program is 92.237487 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[661].mean(axis=0))
d.remove_narrow_spikes_V1(6,1,to_self=True)
plt.plot(d[661].mean(axis=0))
# Out:
# Channel input = 6
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854605 percent complete
# Program is 9.709209 percent complete
# Program is 14.563814 percent complete
# Program is 19.418418 percent complete
# Program is 24.273023 percent complete
# Program is 29.127628 percent complete
# Program is 33.982232 percent complete
# Program is 38.836837 percent complete
# Program is 43.691441 percent complete
# Program is 48.546046 percent complete
# Program is 53.400651 percent complete
# Program is 58.255255 percent complete
# Program is 63.109860 percent complete
# Program is 67.964464 percent complete
# Program is 72.819069 percent complete
# Program is 77.673673 percent complete
# Program is 82.528278 percent complete
# Program is 87.382883 percent complete
# Program is 92.237487 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[771].mean(axis=0))
d.remove_narrow_spikes_V1(7,1,to_self=True)
plt.plot(d[771].mean(axis=0))
# Out:
# Channel input = 7
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854605 percent complete
# Program is 9.709209 percent complete
# Program is 14.563814 percent complete
# Program is 19.418418 percent complete
# Program is 24.273023 percent complete
# Program is 29.127628 percent complete
# Program is 33.982232 percent complete
# Program is 38.836837 percent complete
# Program is 43.691441 percent complete
# Program is 48.546046 percent complete
# Program is 53.400651 percent complete
# Program is 58.255255 percent complete
# Program is 63.109860 percent complete
# Program is 67.964464 percent complete
# Program is 72.819069 percent complete
# Program is 77.673673 percent complete
# Program is 82.528278 percent complete
# Program is 87.382883 percent complete
# Program is 92.237487 percent complete
# Program is 97.092092 percent complete

# %%
plt.plot(d[881].mean(axis=0))
d.remove_narrow_spikes_V1(8,1,to_self=True)
plt.plot(d[881].mean(axis=0))
# Out:
# Channel input = 8
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854605 percent complete
# Program is 9.709209 percent complete
# Program is 14.563814 percent complete
# Program is 19.418418 percent complete
# Program is 24.273023 percent complete
# Program is 29.127628 percent complete
# Program is 33.982232 percent complete
# Program is 38.836837 percent complete
# Program is 43.691441 percent complete
# Program is 48.546046 percent complete
# Program is 53.400651 percent complete
# Program is 58.255255 percent complete
# Program is 63.109860 percent complete
# Program is 67.964464 percent complete
# Program is 72.819069 percent complete
# Program is 77.673673 percent complete
# Program is 82.528278 percent complete
# Program is 87.382883 percent complete
# Program is 92.237487 percent complete
# Program is 97.092092 percent complete

# %%
d=bmxobs.BMXObs("pas/200528_0600","all_auto")

# %%
plt.plot(d[111].mean(axis=0))
d.remove_narrow_spikes_V1(1,1,to_self=True)
plt.plot(d[111].mean(axis=0))
# Out:
# Channel input = 1
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[221].mean(axis=0))
d.remove_narrow_spikes_V1(2,1,to_self=True)
plt.plot(d[221].mean(axis=0))
# Out:
# Channel input = 2
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[331].mean(axis=0))
d.remove_narrow_spikes_V1(3,1,to_self=True)
plt.plot(d[331].mean(axis=0))
# Out:
# Channel input = 3
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[441].mean(axis=0))
d.remove_narrow_spikes_V1(4,1,to_self=True)
plt.plot(d[441].mean(axis=0))
# Out:
# Channel input = 4
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[551].mean(axis=0))
d.remove_narrow_spikes_V1(5,1,to_self=True)
plt.plot(d[551].mean(axis=0))
# Out:
# Channel input = 5
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[661].mean(axis=0))
d.remove_narrow_spikes_V1(6,1,to_self=True)
plt.plot(d[661].mean(axis=0))
# Out:
# Channel input = 6
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[771].mean(axis=0))
d.remove_narrow_spikes_V1(7,1,to_self=True)
plt.plot(d[771].mean(axis=0))
# Out:
# Channel input = 7
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[881].mean(axis=0))
d.remove_narrow_spikes_V1(8,1,to_self=True)
plt.plot(d[881].mean(axis=0))
# Out:
# Channel input = 8
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
d=bmxobs.BMXObs("pas/200527_0600","all_auto")

# %%
plt.plot(d[111].mean(axis=0))
d.remove_narrow_spikes_V1(1,1,to_self=True)
plt.plot(d[111].mean(axis=0))
# Out:
# Channel input = 1
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[221].mean(axis=0))
d.remove_narrow_spikes_V1(2,1,to_self=True)
plt.plot(d[221].mean(axis=0))
# Out:
# Channel input = 2
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[331].mean(axis=0))
d.remove_narrow_spikes_V1(3,1,to_self=True)
plt.plot(d[331].mean(axis=0))
# Out:
# Channel input = 3
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[441].mean(axis=0))
d.remove_narrow_spikes_V1(4,1,to_self=True)
plt.plot(d[441].mean(axis=0))
# Out:
# Channel input = 4
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[551].mean(axis=0))
d.remove_narrow_spikes_V1(5,1,to_self=True)
plt.plot(d[551].mean(axis=0))
# Out:
# Channel input = 5
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[661].mean(axis=0))
d.remove_narrow_spikes_V1(6,1,to_self=True)
plt.plot(d[661].mean(axis=0))
# Out:
# Channel input = 6
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[771].mean(axis=0))
d.remove_narrow_spikes_V1(7,1,to_self=True)
plt.plot(d[771].mean(axis=0))
# Out:
# Channel input = 7
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
plt.plot(d[881].mean(axis=0))
d.remove_narrow_spikes_V1(8,1,to_self=True)
plt.plot(d[881].mean(axis=0))
# Out:
# Channel input = 8
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854652 percent complete
# Program is 9.709303 percent complete
# Program is 14.563955 percent complete
# Program is 19.418607 percent complete
# Program is 24.273259 percent complete
# Program is 29.127910 percent complete
# Program is 33.982562 percent complete
# Program is 38.837214 percent complete
# Program is 43.691866 percent complete
# Program is 48.546517 percent complete
# Program is 53.401169 percent complete
# Program is 58.255821 percent complete
# Program is 63.110472 percent complete
# Program is 67.965124 percent complete
# Program is 72.819776 percent complete
# Program is 77.674428 percent complete
# Program is 82.529079 percent complete
# Program is 87.383731 percent complete
# Program is 92.238383 percent complete
# Program is 97.093035 percent complete

# %%
d=bmxobs.BMXObs("pas/191214_1700","all_auto")

# %%
plt.plot(d[111].mean(axis=0))
d.remove_narrow_spikes_V1(1,1,to_self=True)
plt.plot(d[111].mean(axis=0))
# Out:
# Channel input = 1
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete

# %%
plt.plot(d[221].mean(axis=0))
d.remove_narrow_spikes_V1(2,1,to_self=True)
plt.plot(d[221].mean(axis=0))
# Out:
# Channel input = 2
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete

# %%
plt.plot(d[331].mean(axis=0))
d.remove_narrow_spikes_V1(3,1,to_self=True)
plt.plot(d[331].mean(axis=0))
# Out:
# Channel input = 3
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete

# %%
plt.plot(d[441].mean(axis=0))
d.remove_narrow_spikes_V1(4,1,to_self=True)
plt.plot(d[441].mean(axis=0))
# Out:
# Channel input = 4
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete

# %%
plt.plot(d[551].mean(axis=0))
d.remove_narrow_spikes_V1(5,1,to_self=True)
plt.plot(d[551].mean(axis=0))
# Out:
# Channel input = 5
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete

# %%
plt.plot(d[661].mean(axis=0))
d.remove_narrow_spikes_V1(6,1,to_self=True)
plt.plot(d[661].mean(axis=0))
# Out:
# Channel input = 6
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete

# %%
plt.plot(d[771].mean(axis=0))
d.remove_narrow_spikes_V1(7,1,to_self=True)
plt.plot(d[771].mean(axis=0))
# Out:
# Channel input = 7
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete

# %%
plt.plot(d[881].mean(axis=0))
d.remove_narrow_spikes_V1(8,1,to_self=True)
plt.plot(d[881].mean(axis=0))
# Out:
# Channel input = 8
# Cut input = 1
# Program is 0.000000 percent complete
# Program is 4.854510 percent complete
# Program is 9.709021 percent complete
# Program is 14.563531 percent complete
# Program is 19.418041 percent complete
# Program is 24.272552 percent complete
# Program is 29.127062 percent complete
# Program is 33.981572 percent complete
# Program is 38.836083 percent complete
# Program is 43.690593 percent complete
# Program is 48.545103 percent complete
# Program is 53.399614 percent complete
# Program is 58.254124 percent complete
# Program is 63.108634 percent complete
# Program is 67.963145 percent complete
# Program is 72.817655 percent complete
# Program is 77.672165 percent complete
# Program is 82.526676 percent complete
# Program is 87.381186 percent complete
# Program is 92.235696 percent complete
# Program is 97.090207 percent complete
